# %% [markdown]
# # Computer Vision 2023 Assignment 3: Deep Learning for Perception Tasks
#
# This assignment contains 2 questions. The first question probes understanding of deep learning for classification. The second question is a more challenging classification experiment on a larger dataset. Answer the questions in separate Python notebooks.
#
# ## Question 1: A simple classifier, 20 marks
#
# For this exercise, we provide demo code showing how to train a network on a small dataset called [Fashion-MNIST](https://github.com/zalandoresearch/fashion-mnist). Please run through the code "tutorial-style" to get a sense of what it is doing. Then use the code alongside lecture notes and other resources to understand how to use pytorch libraries to implement, train and use a neural network.
#
# For the Fashion-MNIST dataset the lables from 0-9 correspond to various clothing classes so you might find it convenient to create a python list as follows:
#
# class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
#                'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
#
# You will need to answer various questions about the system, how it operates, the results of experiments with it and make modifications to it yourself. You can change the training scheme and the network structure.
#
# Organize your own text and code cell to show the answer of each questions.
#
# Detailed requirements:
#
# **Q1.1 (1 point)**
#
# Extract 3 images of different types of clothing from the training dataset, print out the size/shape of the training images, and display the three with their corresponding labels.
#
# **Q1.2 (2 points)**
#
# Run the training code for 10 epochs, for different values of the learning rate. Fill in the table below and plot the loss curves for each experiment:
#
# |Lr|Accuracy|
# |---|---|
# |1   |   10.0%   |
# |0.1|     87.5%     |
# |0.01|   83.5%      |
# |0.001  |    70.5%    |
#
#
# **Q1.3 (3 points)**
#
# Report the number of epochs when the accuracy reaches 85%. Fill in the table below and plot the loass curve for each experiment:
#
# |Lr|Accuracy|Epoch|
# |---|---|---|
# |1   |      |     |
# |0.1|     85.7%     |  5  |
# |0.01|     85.0%    |  16  |
# |0.001  |    85%    |  115   |
#
# Explains: for Lr=1, when the accuracy will not be 85%. Here's what I think might be leading the accuracy can't reaching 85%: Firstly, the learning rate is too high, which can cause the optimal solution to be skipped during training and not converge to a high accuracy. Too high a learning rate may also lead to increasing values of the loss function and failure to converge to smaller losses.
#
#
# **Q1.4 (2 points)**
#
# Compare the results in table 1 and table 2, what is your observation and your understanding of learning rate?
#
#
# **Q1.5 (5 points)**
#
# Build a wider network by modifying the code that constructs the network so that the hidden layer(s) contain more perceptrons, and record the accuracy along with the number of trainable parameters in your model.  Now modify the oroginal network to be deeper instead of wider (i.e. by adding more hidden layers). Record your accuracy and network size findings. Plot the loss curve for each experiment. Write down your conclusions about changing the network structure?
#
# When lr=1e-3, epochs=10:
# base case parameters:
#     The first layer: 28x28x512 + 512 = 401920
#     The second layer: 512x512 + 512 = 262656
#     The third layer: 512x10 + 10 = 5130
#     401920 + 262656 + 5130 = 669706
#
# wider case parameters:
#     The first layer: 1024x784 + 1024 = 803840
#     The second layer: 1024x1024 + 1024 = 1049600
#     The third layer: 10x1024 + 10 = 10250
#     803840 + 1049600 + 10250 = 1863690
#
# deeper case parameters:
#     The first layer: 512x784 + 512 = 401920
#     The second layer: 512x512 + 512 = 262656
#     The third layer: 256x512 + 256 = 131328
#     The forth layer: 10x256 + 10 = 2570
#     401920 + 262656 + 131328 + 2570 = 798474
#
# |Structures|Accuracy|Parameters|
# |---|---|---|
# |Base   |   70.8%   |66706|
# |Deeper|     65.4%     |798474|
# |Wider|    73.2%     |1863690|
#
#
# **Q1.6 (2 points)**
#
# Calculate the mean of the gradients of the loss to all trainable parameters. Plot the gradients curve for the first 100 training steps. What are your observations? Note that this gradients will be saved with the training weight automatically after you call loss.backwards(). Hint: the mean of the gradients decrease.
#
# For more exlanation of q1.7, you could refer to the following simple instructions: https://colab.research.google.com/drive/1XAsyNegGSvMf3_B6MrsXht7-fHqtJ7OW?usp=sharing
#
# **Q1.7 (5 points)**
#
# Modify the network structure and training/test to use a small convolutional neural network instead of an MLP. Discuss your findings with rehgard to convergence, accuracy and number of parameters, relative to MLPs.
#
# Hint: Look at the structure of the CNN in the Workshop 3 examples.

# %% [markdown]
# ## Answers:
# **Q 1.3**
#
# Explains:
# for Lr=1, when the accuracy will not be 85%. Here's what I think might be leading the accuracy can't reaching 85%: Firstly, the learning rate is too high, which can cause the optimal solution to be skipped during training and not converge to a high accuracy. Too high a learning rate may also lead to increasing values of the loss function and failure to converge to smaller losses.
#
# **Q 1.4**
# Observation and understanding:
#
# From the table 1, after 10 epochs, when the learning rate is 1.0, the accuracy is the lowest, which is 10%. When the learning rate is 0.1, the accuracy is 87.5%. After a learning rate of 0.1, the lower the learning rate, the progressively lower the accuracy.
#
# From the table 2, with the learning rate of 1.0, the accuracy has remained at 10%. However, when the learning rate of 0.01, the training to reach an accuracy of 85% is minimal comparing with others, which costs 4 epochs. As the learning rate decreases, the more training is required to reach 85% accuracy.
#
# To sum up, higher learning rates may lead to instability in the training process. If the learning rate is too high, it may cause the optimal solution to be skipped during training and not converge to a high accuracy. Too high a learning rate may also lead to increasing values of the loss function and failure to converge to smaller losses.Lower learning rates may result in a slower convergence of the training process, requiring more epochs to achieve the target accuracy. Therefore, too high or too low learning rates can lead to performance degradation. Appropriate learning rate selection can achieve target accuracy in a shorter period of time.
#
# **Q 1.5**
# Conclusion:
#
# When the network becomes wider, it makes increases of model's ability to capture complex patterns in the data. So it can improve accuracy as the network has more resources to learn from the data. The accuracy under wider network structure is the highest.
#
# From the loss curve of deeper network, it shows a distinctive pattern compared to the other two curves. In the early epochs, the loss values for the deeper network are relatively high and show a slow decline. However, starting from the fourth epoch, the loss values for the deeper network experience a noticeable drop. And the accuracy under such a network is lower than the base case. It demostrates that simply increasing the depth of the network may cause performance degradation.
#
# Parameters may have an effect on accuracy. Increasing the width of the network generally improves accuracy, while increasing the depth of the network may not always lead to better performance and can even result in decreased accuracy if not properly optimized.
#
# **Q 1.6**
# Observation:
#
# 1. The mean of the gradients decreases over the training steps.
# 2. The gradients curve exhibits oscillatory behavior
# 3. The closer the step is to 100, the larger the oscillation is.
#
# **Q 1.7**
# Findings:
#
# Convergence: Using CNNs leads to faster convergence. From the Q 1.7 loss curve, we can observe that the convergence using CNNs is faster than using MLPs.
#
# Accuracy: In terms of average loss, using CNNs leads to better accuracy relative to MLPs.
#
# Number of Parameters: Compared to MLP, CNN contains convolutional and pooling layers that require more parameters to process the spatial structure of image data. Therefore, the number of parameters of CNN is more than MLP.

# %%
import numpy as np # This is for mathematical operations

# this is used in plotting 
import matplotlib.pyplot as plt 
import time
import pylab as pl
from IPython import display

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#### Tutorial Code
####PyTorch has two primitives to work with data: torch.utils.data.DataLoader and torch.utils.data.Dataset. 
#####Dataset stores samples and their corresponding labels, and DataLoader wraps an iterable around the Dataset.
import torch
from torch import nn
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
import matplotlib.pyplot as plt

# Download training data from open datasets. 
##Every TorchVision Dataset includes two arguments: 
##transform and target_transform to modify the samples and labels respectively.

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# %% [markdown]
# **NOTE**: For consistency with the original data set, we call our validation data "test_data". It is important to keep in mind though that we are using the data for model validation and not for testing the final, trained model (which requires data not used when training the model parameters).
#
# We pass the Dataset as an argument to DataLoader. This wraps an iterable over our dataset and supports automatic batching, sampling, shuffling, and multiprocess data loading. Here we define a batch size of 64, i.e. each element in the dataloader iterable will return a batch of 64 features and labels.

# %%
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print("Shape of X [N, C, H, W]: ", X.shape)
    print("Shape of y: ", y.shape, y.dtype)
    break
# Out:
# Shape of X [N, C, H, W]:  torch.Size([64, 1, 28, 28])
# Shape of y:  torch.Size([64]) torch.int64

# %% [markdown]
# Add in a code cell to inspect the training data, as per Q1.1. Each element of the training_data structure has a greyscale image (which you can use plt.imshow(img[0,:,:]) to display, just like you did in previous assignments.

# %%
# Code cell for training image display

def display(img, caption=''):
    plt.figure()
    img = np.clip(img, 0, 1)
    plt.imshow(np.squeeze(img),cmap='gray')
    plt.title(caption)
    plt.axis('on')
    plt.show()

# %% [markdown]
# To define a neural network in PyTorch, we create a class that inherits from nn.Module. We define the layers of the network in the init function and specify how data will pass through the network in the forward function. To accelerate operations in the neural network, we move it to the GPU if available.

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using {} device".format(device))

import torch.nn.functional as F

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10)
       )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)

        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cpu device
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
###Define the loss function and the optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %% [markdown]
# In a single training loop, the model makes predictions on the training dataset (fed to it in batches), and backpropagates the prediction error to adjust the model’s parameters.

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
##Define a test function
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Accuracy: {(100*correct):>0.1f}%\n")
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
#Train and test the model
epochs = 5
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.296455  [    0/60000]
# loss: 2.290246  [ 6400/60000]
# loss: 2.273947  [12800/60000]
# loss: 2.275065  [19200/60000]
# loss: 2.254837  [25600/60000]
# loss: 2.222296  [32000/60000]
# loss: 2.232985  [38400/60000]
# loss: 2.194180  [44800/60000]
# loss: 2.192413  [51200/60000]
# loss: 2.175948  [57600/60000]
# Test Error:
#  Accuracy: 47.0%, Avg loss: 2.162213
#
# Epoch 2
# -------------------------------
# loss: 2.164245  [    0/60000]
# loss: 2.156499  [ 6400/60000]
# loss: 2.106079  [12800/60000]
# loss: 2.126893  [19200/60000]
# loss: 2.068096  [25600/60000]
# loss: 2.018291  [32000/60000]
# loss: 2.043822  [38400/60000]
# loss: 1.960738  [44800/60000]
# loss: 1.967467  [51200/60000]
# loss: 1.910964  [57600/60000]
# Test Error:
#  Accuracy: 54.0%, Avg loss: 1.899423
#
# Epoch 3
# -------------------------------
# loss: 1.923616  [    0/60000]
# loss: 1.895067  [ 6400/60000]
# loss: 1.786780  [12800/60000]
# ...

# %% [markdown]
# **Q 1.1**

# %%
# Q 1.1
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

selected_images = []
selected_labels = []

for image, label in training_data:
    if label not in selected_labels:
        selected_labels.append(label)
        selected_images.append(image)
        if len(selected_labels) == 3:
            break

for i in range(len(selected_images)):
    img = selected_images[i] / 255.0
    display(img, caption=f"Label: {class_names[selected_labels[i]]}")
    print("Shape of image:", image.shape)
# Out:
# Shape of image: torch.Size([1, 28, 28])
# Shape of image: torch.Size([1, 28, 28])
# Shape of image: torch.Size([1, 28, 28])

# %% [markdown]
# **Q 1.2**

# %%
# Q1.2 lr=1
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.287932  [    0/60000]
# loss: 2.167448  [ 6400/60000]
# loss: 2.286654  [12800/60000]
# loss: 1.867347  [19200/60000]
# loss: 2.458570  [25600/60000]
# loss: 2.410993  [32000/60000]
# loss: 1.813387  [38400/60000]
# loss: 1.738690  [44800/60000]
# loss: 2.433231  [51200/60000]
# loss: 2.344198  [57600/60000]
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.322686
#
# Epoch 2
# -------------------------------
# loss: 2.315483  [    0/60000]
# loss: 1.688819  [ 6400/60000]
# loss: 1.646562  [12800/60000]
# loss: 1.352352  [19200/60000]
# loss: 1.518826  [25600/60000]
# loss: 1.523325  [32000/60000]
# loss: 1.405199  [38400/60000]
# loss: 1.769552  [44800/60000]
# loss: 2.997437  [51200/60000]
# loss: 1.845281  [57600/60000]
# Test Error:
#  Accuracy: 29.7%, Avg loss: 1.611163
#
# Epoch 3
# -------------------------------
# loss: 1.572700  [    0/60000]
# loss: 1.736820  [ 6400/60000]
# loss: 1.641840  [12800/60000]
# ...

# %%
# lr=1, the loss curves 

epochs = range(1, 11)
losses1 = [2.322686, 1.611163, 1.741036, 1.725323, 1.712471, 1.758612, 1.782377, 1.731095, 1.713281, 2.305845]

plt.plot(epochs, losses1)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Q1.2 Loss Curve for lr=1')
plt.grid(True)
plt.show()

# %%
# Q 1.1 lr=0.1
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.307857  [    0/60000]
# loss: 0.899391  [ 6400/60000]
# loss: 0.578846  [12800/60000]
# loss: 0.711169  [19200/60000]
# loss: 0.608401  [25600/60000]
# loss: 0.514410  [32000/60000]
# loss: 0.550467  [38400/60000]
# loss: 0.604026  [44800/60000]
# loss: 0.588472  [51200/60000]
# loss: 0.461308  [57600/60000]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.550767
#
# Epoch 2
# -------------------------------
# loss: 0.429133  [    0/60000]
# loss: 0.435738  [ 6400/60000]
# loss: 0.378620  [12800/60000]
# loss: 0.444091  [19200/60000]
# loss: 0.423004  [25600/60000]
# loss: 0.453508  [32000/60000]
# loss: 0.422284  [38400/60000]
# loss: 0.519741  [44800/60000]
# loss: 0.493523  [51200/60000]
# loss: 0.427479  [57600/60000]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.460116
#
# Epoch 3
# -------------------------------
# loss: 0.311741  [    0/60000]
# loss: 0.358934  [ 6400/60000]
# loss: 0.322020  [12800/60000]
# ...

# %%
# Q 1.2 lr=0.1
epochs = range(1, 11)
losses = [0.550767, 0.460116 , 0.428349, 0.406594 , 0.383623, 0.367193 , 0.355793, 0.348784, 0.344004, 0.341031]

plt.plot(epochs, losses, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Q1.2 Loss Curve lr=0.1')
plt.grid(True)
plt.show()

# %%
# Q 1.2 lr=0.01
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.302445  [    0/60000]
# loss: 2.157541  [ 6400/60000]
# loss: 1.794379  [12800/60000]
# loss: 1.502659  [19200/60000]
# loss: 1.132450  [25600/60000]
# loss: 1.036272  [32000/60000]
# loss: 0.993879  [38400/60000]
# loss: 0.854651  [44800/60000]
# loss: 0.865516  [51200/60000]
# loss: 0.810260  [57600/60000]
# Test Error:
#  Accuracy: 71.7%, Avg loss: 0.788039
#
# Epoch 2
# -------------------------------
# loss: 0.791823  [    0/60000]
# loss: 0.847493  [ 6400/60000]
# loss: 0.585520  [12800/60000]
# loss: 0.779828  [19200/60000]
# loss: 0.648361  [25600/60000]
# loss: 0.637940  [32000/60000]
# loss: 0.705460  [38400/60000]
# loss: 0.666622  [44800/60000]
# loss: 0.699383  [51200/60000]
# loss: 0.639339  [57600/60000]
# Test Error:
#  Accuracy: 77.9%, Avg loss: 0.630978
#
# Epoch 3
# -------------------------------
# loss: 0.560943  [    0/60000]
# loss: 0.655610  [ 6400/60000]
# loss: 0.436130  [12800/60000]
# ...

# %%
# Q 1.2 lr=0.01
epochs = range(1, 11)
losses = [0.788039, 0.630978, 0.570014, 0.539031, 0.518934, 0.503453, 0.490780, 0.480420, 0.470850, 0.462142]

plt.plot(epochs, losses, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Q1.2 Loss Curve lr=0.01')
plt.grid(True)
plt.show()

# %%
# Q 1.2 lr=0.001
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.312107  [    0/60000]
# loss: 2.300492  [ 6400/60000]
# loss: 2.280398  [12800/60000]
# loss: 2.271828  [19200/60000]
# loss: 2.263931  [25600/60000]
# loss: 2.236567  [32000/60000]
# loss: 2.233986  [38400/60000]
# loss: 2.215607  [44800/60000]
# loss: 2.206069  [51200/60000]
# loss: 2.170315  [57600/60000]
# Accuracy: 48.7%
#
# Test Error:
#  Accuracy: 48.7%, Avg loss: 2.173624
#
# Epoch 2
# -------------------------------
# loss: 2.180354  [    0/60000]
# loss: 2.173458  [ 6400/60000]
# loss: 2.119159  [12800/60000]
# loss: 2.130594  [19200/60000]
# loss: 2.096727  [25600/60000]
# loss: 2.031731  [32000/60000]
# loss: 2.049283  [38400/60000]
# loss: 1.988928  [44800/60000]
# loss: 1.988255  [51200/60000]
# loss: 1.905162  [57600/60000]
# Accuracy: 58.4%
#
# Test Error:
#  Accuracy: 58.4%, Avg loss: 1.920036
#
# Epoch 3
# -------------------------------
# loss: 1.945055  [    0/60000]
# loss: 1.921481  [ 6400/60000]
# ...

# %%
# Q 1.2 lr=0.001
epochs = range(1, 11)
losses = [2.147477, 1.873557, 1.511791, 1.249712, 1.084101, 0.976156, 0.902400, 0.849457,0.809598, 0.778114]

plt.plot(epochs, losses, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Q1.2 Loss Curve lr=0.001')
plt.grid(True)
plt.show()

# %% [markdown]
# **Q1.3**

# %%
def testForLossArray(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Accuracy: {(100*correct):>0.1f}%\n")
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return test_loss

# %%
# Q1.3 lr=1
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1)

epochs = 50
loss_array_1 = []
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    loss_array_1.append(testForLossArray(test_dataloader, model, loss_fn))
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.293334  [    0/60000]
# loss: 2.046764  [ 6400/60000]
# loss: 2.077293  [12800/60000]
# loss: 1.882672  [19200/60000]
# loss: 1.729771  [25600/60000]
# loss: 2.199642  [32000/60000]
# loss: 1.995920  [38400/60000]
# loss: 2.030064  [44800/60000]
# loss: 1.732848  [51200/60000]
# loss: 1.652970  [57600/60000]
# Accuracy: 34.5%
#
# Test Error:
#  Accuracy: 34.5%, Avg loss: 1.603369
#
# Epoch 2
# -------------------------------
# loss: 1.615406  [    0/60000]
# loss: 1.471460  [ 6400/60000]
# loss: 1.779671  [12800/60000]
# loss: 1.634527  [19200/60000]
# loss: 1.422016  [25600/60000]
# loss: 1.678454  [32000/60000]
# loss: 1.416501  [38400/60000]
# loss: 1.404397  [44800/60000]
# loss: 1.556541  [51200/60000]
# loss: 2.326347  [57600/60000]
# Accuracy: 10.4%
#
# Test Error:
#  Accuracy: 10.4%, Avg loss: 2.302334
#
# Epoch 3
# -------------------------------
# loss: 2.300374  [    0/60000]
# loss: 1.721178  [ 6400/60000]
# ...

# %%
epochsRange = range(1,51)
plt.plot(epochsRange, loss_array_1, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Q1.3  Loss Curve lr=1')
plt.grid(True)
plt.show()

# %%
# Q1.3 lr=0.1
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

epochs = 20
loss_array_2 = []
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    loss_array_2.append(testForLossArray(test_dataloader, model, loss_fn))
print("Done!")

print(loss_array_2)
# Out:
# Epoch 1
# -------------------------------
# loss: 2.300871  [    0/60000]
# loss: 0.915662  [ 6400/60000]
# loss: 0.573142  [12800/60000]
# loss: 0.696502  [19200/60000]
# loss: 0.613057  [25600/60000]
# loss: 0.509192  [32000/60000]
# loss: 0.543345  [38400/60000]
# loss: 0.602951  [44800/60000]
# loss: 0.595958  [51200/60000]
# loss: 0.457805  [57600/60000]
# Accuracy: 79.0%
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.553192
#
# Epoch 2
# -------------------------------
# loss: 0.430917  [    0/60000]
# loss: 0.440230  [ 6400/60000]
# loss: 0.369411  [12800/60000]
# loss: 0.428918  [19200/60000]
# loss: 0.418868  [25600/60000]
# loss: 0.452460  [32000/60000]
# loss: 0.418959  [38400/60000]
# loss: 0.505508  [44800/60000]
# loss: 0.511238  [51200/60000]
# loss: 0.423429  [57600/60000]
# Accuracy: 82.2%
#
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.469186
#
# Epoch 3
# -------------------------------
# loss: 0.324933  [    0/60000]
# loss: 0.363464  [ 6400/60000]
# ...

# %%
epochsRange = range(1,21)
plt.plot(epochsRange, loss_array_2, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Q1.3 Loss Curve lr=0.1')
plt.grid(True)
plt.show()

# %%
# Q1.3 lr=0.01
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

epochs = 20
loss_array_3 = []
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    loss_array_3.append(testForLossArray(test_dataloader, model, loss_fn))
print("Done!")

print(loss_array_3)
# Out:
# Epoch 1
# -------------------------------
# loss: 2.293316  [    0/60000]
# loss: 2.143126  [ 6400/60000]
# loss: 1.753298  [12800/60000]
# loss: 1.470623  [19200/60000]
# loss: 1.126503  [25600/60000]
# loss: 1.028882  [32000/60000]
# loss: 1.003661  [38400/60000]
# loss: 0.872772  [44800/60000]
# loss: 0.861036  [51200/60000]
# loss: 0.802651  [57600/60000]
# Accuracy: 71.5%
#
# Test Error:
#  Accuracy: 71.5%, Avg loss: 0.784618
#
# Epoch 2
# -------------------------------
# loss: 0.791308  [    0/60000]
# loss: 0.837245  [ 6400/60000]
# loss: 0.580861  [12800/60000]
# loss: 0.780685  [19200/60000]
# loss: 0.675692  [25600/60000]
# loss: 0.642152  [32000/60000]
# loss: 0.713314  [38400/60000]
# loss: 0.698373  [44800/60000]
# loss: 0.705881  [51200/60000]
# loss: 0.625367  [57600/60000]
# Accuracy: 77.9%
#
# Test Error:
#  Accuracy: 77.9%, Avg loss: 0.632060
#
# Epoch 3
# -------------------------------
# loss: 0.563399  [    0/60000]
# loss: 0.648575  [ 6400/60000]
# ...

# %%
epochsRange = range(1,21)
plt.plot(epochsRange, loss_array_3, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Q1.3 Loss Curve lr=0.01')
plt.grid(True)
plt.show()

# %%
# Q1.3 lr=0.001
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

epochs = 120
loss_array_4 = []
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    loss_array_4.append(testForLossArray(test_dataloader, model, loss_fn))
print("Done!")

print(loss_array_4)
# Out:
# Epoch 1
# -------------------------------
# loss: 2.304104  [    0/60000]
# loss: 2.291621  [ 6400/60000]
# loss: 2.279293  [12800/60000]
# loss: 2.279179  [19200/60000]
# loss: 2.249622  [25600/60000]
# loss: 2.231504  [32000/60000]
# loss: 2.234385  [38400/60000]
# loss: 2.204115  [44800/60000]
# loss: 2.200670  [51200/60000]
# loss: 2.178216  [57600/60000]
# Accuracy: 43.0%
#
# Test Error:
#  Accuracy: 43.0%, Avg loss: 2.166182
#
# Epoch 2
# -------------------------------
# loss: 2.171202  [    0/60000]
# loss: 2.169863  [ 6400/60000]
# loss: 2.117579  [12800/60000]
# loss: 2.133841  [19200/60000]
# loss: 2.085015  [25600/60000]
# loss: 2.022685  [32000/60000]
# loss: 2.050675  [38400/60000]
# loss: 1.974606  [44800/60000]
# loss: 1.981832  [51200/60000]
# loss: 1.914087  [57600/60000]
# Accuracy: 55.3%
#
# Test Error:
#  Accuracy: 55.3%, Avg loss: 1.907773
#
# Epoch 3
# -------------------------------
# loss: 1.934645  [    0/60000]
# loss: 1.918030  [ 6400/60000]
# ...

# %%
epochsRange = range(1,121)
plt.plot(epochsRange, loss_array_4, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Q1.3 Loss Curve lr=0.001')
plt.grid(True)
plt.show()

# %% [markdown]
# **Q1.5**

# %%
# Q1.5 base case network
# lr=1e-3, epochs=10
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("base case network result Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.300234  [    0/60000]
# loss: 2.294273  [ 6400/60000]
# loss: 2.273298  [12800/60000]
# loss: 2.262319  [19200/60000]
# loss: 2.241638  [25600/60000]
# loss: 2.221539  [32000/60000]
# loss: 2.232143  [38400/60000]
# loss: 2.197703  [44800/60000]
# loss: 2.186594  [51200/60000]
# loss: 2.155979  [57600/60000]
# Accuracy: 44.2%
#
# Test Error:
#  Accuracy: 44.2%, Avg loss: 2.148057
#
# Epoch 2
# -------------------------------
# loss: 2.165258  [    0/60000]
# loss: 2.151641  [ 6400/60000]
# loss: 2.090298  [12800/60000]
# loss: 2.098266  [19200/60000]
# loss: 2.044172  [25600/60000]
# loss: 1.995264  [32000/60000]
# loss: 2.020862  [38400/60000]
# loss: 1.938517  [44800/60000]
# loss: 1.937502  [51200/60000]
# loss: 1.865017  [57600/60000]
# Accuracy: 55.8%
#
# Test Error:
#  Accuracy: 55.8%, Avg loss: 1.860560
#
# Epoch 3
# -------------------------------
# loss: 1.899176  [    0/60000]
# loss: 1.867395  [ 6400/60000]
# ...

# %%
# Q1.5 wider network
# lr=1e-3, epochs=10

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using {} device".format(device))

import torch.nn.functional as F

# wider network case:
class NeuralNetworkWider(nn.Module):
    def __init__(self):
        super(NeuralNetworkWider, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 1024),
            nn.ReLU(),
            nn.Linear(1024, 1024),
            nn.ReLU(),
            nn.Linear(1024, 10)
       )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)

        return logits

model = NeuralNetworkWider().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Using cpu device
# NeuralNetworkWider(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=1024, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# Epoch 1
# -------------------------------
# loss: 2.309007  [    0/60000]
# loss: 2.279044  [ 6400/60000]
# loss: 2.254515  [12800/60000]
# loss: 2.246081  [19200/60000]
# loss: 2.223565  [25600/60000]
# loss: 2.174668  [32000/60000]
# loss: 2.192741  [38400/60000]
# loss: 2.143442  [44800/60000]
# loss: 2.137524  [51200/60000]
# loss: 2.086525  [57600/60000]
# Accuracy: 52.6%
#
# Test Error:
#  Accuracy: 52.6%, Avg loss: 2.081291
#
# Epoch 2
# -------------------------------
# loss: 2.097217  [    0/60000]
# loss: 2.074814  [ 6400/60000]
# loss: 1.997851  [12800/60000]
# loss: 2.023493  [19200/60000]
# ...

# %%
# Q1.5 deeper network
# lr=1e-3, epochs=10

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using {} device".format(device))

import torch.nn.functional as F

# deeper network case:
class NeuralNetworkDeeper(nn.Module):
    def __init__(self):
        super(NeuralNetworkDeeper, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 256),  # Add a hidden layer
            nn.ReLU(),
            nn.Linear(256, 10)
       )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)

        return logits

model = NeuralNetworkDeeper().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Using cpu device
# NeuralNetworkDeeper(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=256, out_features=10, bias=True)
#   )
# )
# Epoch 1
# -------------------------------
# loss: 2.298599  [    0/60000]
# loss: 2.298650  [ 6400/60000]
# loss: 2.293383  [12800/60000]
# loss: 2.296075  [19200/60000]
# loss: 2.290977  [25600/60000]
# loss: 2.284059  [32000/60000]
# loss: 2.288858  [38400/60000]
# loss: 2.278354  [44800/60000]
# loss: 2.276520  [51200/60000]
# loss: 2.277612  [57600/60000]
# Accuracy: 36.8%
#
# Test Error:
#  Accuracy: 36.8%, Avg loss: 2.272651
#
# Epoch 2
# -------------------------------
# loss: 2.272388  [    0/60000]
# loss: 2.274053  [ 6400/60000]
# ...

# %%
# Q1.5 loss curve
# lr=0.1
epochs = range(1, 11)
losses1 = [2.148057, 1.860560, 1.485658, 1.228622, 1.073589, 0.974368, 0.906088, 0.855999, 0.817357, 0.786243]
losses2 = [2.081291, 1.713857, 1.340369, 1.118089, 0.988237, 0.905986, 0.849517, 0.807857, 0.775106, 0.747956]
losses3 = [2.272651, 2.228389, 2.139335, 1.947176, 1.625628, 1.352524, 1.183824, 1.074243, 0.994395, 0.933035]
plt.plot(epochs, losses1, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Q1.5 base case Loss Curve')
plt.grid(True)
plt.show()

plt.plot(epochs, losses2, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Q1.5 wider network Loss Curve')
plt.grid(True)
plt.show()

plt.plot(epochs, losses3, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Q1.5 deeper network Loss Curve')
plt.grid(True)
plt.show()

# %% [markdown]
# **Q1.6**

# %%
# Q1.6 calculating mean gradients
mean_gradients = []

# Define a train function
def trainForGrad(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()

    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()        
        
        grad = 0
        count = 0
        for params in model.parameters():
            if params.grad is not None:
                grad += params.grad.mean()
                count += 1
        if count > 0:
            mean_gradients.append(grad / count)
        
        optimizer.step()
        
        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
learning_rates = [0.01]
epochs = 2

for i in learning_rates:
    model = NeuralNetwork().to(device)
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=i)
    
    for t in range(epochs):    
        print(f"Epoch {t+1}\n-------------------------------")
        trainForGrad(train_dataloader, model, loss_fn, optimizer)
        test(test_dataloader, model, loss_fn)

plt.plot(mean_gradients[:100])      # first 100 training steps
plt.xlabel("step")
plt.ylabel("mean gradient")
plt.grid(True)
plt.title("Q 1.6 - mean of the gradients of the loss to all trainable parameters")
plt.show()
# Out:
# Epoch 1
# -------------------------------
# loss: 2.306456  [    0/60000]
# loss: 2.175587  [ 6400/60000]
# loss: 1.845667  [12800/60000]
# loss: 1.552805  [19200/60000]
# loss: 1.178730  [25600/60000]
# loss: 1.047650  [32000/60000]
# loss: 1.004628  [38400/60000]
# loss: 0.873706  [44800/60000]
# loss: 0.867797  [51200/60000]
# loss: 0.810450  [57600/60000]
# Accuracy: 71.3%
#
# Test Error:
#  Accuracy: 71.3%, Avg loss: 0.796054
#
# Epoch 2
# -------------------------------
# loss: 0.800819  [    0/60000]
# loss: 0.862753  [ 6400/60000]
# loss: 0.594246  [12800/60000]
# loss: 0.780692  [19200/60000]
# loss: 0.680609  [25600/60000]
# loss: 0.640000  [32000/60000]
# loss: 0.713497  [38400/60000]
# loss: 0.684490  [44800/60000]
# loss: 0.695074  [51200/60000]
# loss: 0.637409  [57600/60000]
# Accuracy: 77.8%
#
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.635814

# %% [markdown]
# **Q1.7**

# %%
# Q 1.7
# Modify the network structure and training/test to use a small convolutional neural network
# instead of an MLP. Discuss your findings with rehgard to convergence, accuracy and number of parameters, relative to MLPs.  
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(1, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 4 * 4, 512)
        self.fc2 = nn.Linear(512, 512)
        self.fc3 = nn.Linear(512, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


net = Net()
net.to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.1)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, net, loss_fn, optimizer)
    test(test_dataloader, net, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.299306  [    0/60000]
# loss: 1.091726  [ 6400/60000]
# loss: 0.583284  [12800/60000]
# loss: 0.709359  [19200/60000]
# loss: 0.641093  [25600/60000]
# loss: 0.566245  [32000/60000]
# loss: 0.478692  [38400/60000]
# loss: 0.573547  [44800/60000]
# loss: 0.544724  [51200/60000]
# loss: 0.428881  [57600/60000]
# Accuracy: 82.1%
#
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.487671
#
# Epoch 2
# -------------------------------
# loss: 0.415834  [    0/60000]
# loss: 0.422605  [ 6400/60000]
# loss: 0.330085  [12800/60000]
# loss: 0.416952  [19200/60000]
# loss: 0.499390  [25600/60000]
# loss: 0.502925  [32000/60000]
# loss: 0.363271  [38400/60000]
# loss: 0.523148  [44800/60000]
# loss: 0.560593  [51200/60000]
# loss: 0.349344  [57600/60000]
# Accuracy: 85.2%
#
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.407661
#
# Epoch 3
# -------------------------------
# loss: 0.296020  [    0/60000]
# loss: 0.328368  [ 6400/60000]
# ...

# %%
# Q1.7 - CNN
epochs = range(1, 11)
lossesCNN = [0.487671, 0.407661, 0.381875, 0.374822, 0.361748, 0.352189, 0.342563, 0.344289, 0.339488, 0.342248]
plt.plot(epochs, lossesCNN, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Q1.7 loss curve - CNN')
plt.grid(True)
plt.show()

# Q1.7 - MLP:
lossesMLP = [0.550767, 0.460116 , 0.428349, 0.406594 , 0.383623, 0.367193 , 0.355793, 0.348784, 0.344004, 0.341031]
plt.plot(epochs, lossesMLP, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Q1.7 loss curve - MLP')
plt.grid(True)
plt.show()
